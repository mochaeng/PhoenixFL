# %%
import pandas as pd
import numpy as np
from scipy import stats
from typing import List, Tuple

pd.set_option('display.max_columns', None)

# %%
file_extension = "parquet"
CLIENTS_PATH: List[Tuple[str, str]] = [
    ("client-1: ToN", f"NF-TON-IOT-V2.{file_extension}"),
    ("client-2: BoT", f"NF-BOT-IOT-V2.{file_extension}"),
    ("client-3: UNSW", f"NF-UNSW-NB15-V2.{file_extension}"),
    ("client-4: CSE", f"NF-CSE-CIC-IDS2018-V2.{file_extension}"),
    ("centralized", f"centralized.{file_extension}"),
]

path_to_datasets = "../datasets/pre-processed/train-test"
client_name, file_name = CLIENTS_PATH[0]
name = file_name.split(".")[0]

df = pd.read_parquet(f"{path_to_datasets}/{client_name}/{name}_train.parquet")
df.head()
# Out:
#   IPV4_SRC_ADDR  L4_SRC_PORT  IPV4_DST_ADDR  L4_DST_PORT  PROTOCOL  L7_PROTO  \
# 0  192.168.1.32        45554    192.168.1.1           53        17       0.0
# 1  192.168.1.32        45274  192.168.1.195           80         6       7.0
# 2  192.168.1.32        53879  192.168.1.180         1433         6     114.0
# 3  192.168.1.30        57294  192.168.1.194           80         6       7.0
# 4  192.168.1.31        49600  192.168.1.190          110         6       2.0
#
#    IN_BYTES  IN_PKTS  OUT_BYTES  OUT_PKTS  TCP_FLAGS  CLIENT_TCP_FLAGS  \
# 0        68        1         68         1          0                 0
# 1       901       15       3543        13         27                27
# 2        44        1          0         0          2                 2
# 3       216        4        180         3         18                18
# 4       378        6        388         6         31                30
#
#    SERVER_TCP_FLAGS  FLOW_DURATION_MILLISECONDS  DURATION_IN  DURATION_OUT  \
# 0                 0                           0            0             0
# 1                27                     4294561          406           406
# 2                 0                           0            0             0
# 3                18                     4294952           15            15
# 4                27                           0            0             0
#
#    MIN_TTL  MAX_TTL  LONGEST_FLOW_PKT  SHORTEST_FLOW_PKT  MIN_IP_PKT_LEN  \
# 0        0        0                68                 68              68
# 1       64       64              1500                 40              40
# 2        0        0                44                 44               0
# 3       64       64                60                 52              52
# 4       64       64               104                 52              52
#
#    MAX_IP_PKT_LEN  SRC_TO_DST_SECOND_BYTES  DST_TO_SRC_SECOND_BYTES  \
# 0              68                     68.0                     68.0
# 1            1500                    901.0                   3543.0
# 2              44                     44.0                      0.0
# 3              60                    216.0                    180.0
# 4             104                    378.0                    388.0
#
#    RETRANSMITTED_IN_BYTES  RETRANSMITTED_IN_PKTS  RETRANSMITTED_OUT_BYTES  \
# 0                       0                      0                        0
# 1                     126                      1                        0
# 2                       0                      0                        0
# 3                       0                      0                        0
# 4                       0                      0                        0
#
#    RETRANSMITTED_OUT_PKTS  SRC_TO_DST_AVG_THROUGHPUT  \
# 0                       0                     544000
# 1                       0                      16000
# 2                       0                     352000
# 3                       0                     104000
# 4                       0                    3024000
#
#    DST_TO_SRC_AVG_THROUGHPUT  NUM_PKTS_UP_TO_128_BYTES  \
# 0                     544000                         2
# 1                      64000                        24
# 2                          0                         1
# 3                      88000                         7
# 4                    3104000                        12
#
#    NUM_PKTS_128_TO_256_BYTES  NUM_PKTS_256_TO_512_BYTES  \
# 0                          0                          0
# 1                          1                          0
# 2                          0                          0
# 3                          0                          0
# 4                          0                          0
#
#    NUM_PKTS_512_TO_1024_BYTES  NUM_PKTS_1024_TO_1514_BYTES  TCP_WIN_MAX_IN  \
# 0                           0                            0               0
# 1                           2                            1           29200
# 2                           0                            0            1024
# 3                           0                            0           29200
# 4                           0                            0           29200
#
#    TCP_WIN_MAX_OUT  ICMP_TYPE  ICMP_IPV4_TYPE  DNS_QUERY_ID  DNS_QUERY_TYPE  \
# 0                0          0               0         49261              28
# 1            65535      32256             126             0               0
# 2                0          0               0             0               0
# 3             5792          0               0             0               0
# 4            28960          0               0             0               0
#
#    DNS_TTL_ANSWER  FTP_COMMAND_RET_CODE  Label    Attack
# 0               0                     0      1       xss
# 1               0                     0      1  password
# 2               0                     0      0    Benign
# 3               0                     0      1      ddos
# 4               0                     0      0    Benign
