# %%
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_parquet("../../datasets/pre-processed/NF-UNSW-NB15-v2.parquet")

df
# Out:
#          L4_SRC_PORT  L4_DST_PORT  PROTOCOL  L7_PROTO  IN_BYTES  IN_PKTS  \
# 878316          5410           21         6       1.0      1493       27
# 2022162        24473        22521         6       0.0      5486       96
# 352143         16241         6881         6       0.0      1540       16
# 1977974        58220         5190         6       0.0      2062       24
# 2086978        65183           53        17       0.0       146        2
# ...              ...          ...       ...       ...       ...      ...
# 2370827        63142           25         6       3.0     37230       52
# 2000931        51951           80         6       7.0      1036        8
# 269949         61826          111        17       0.0       568        4
# 1905472        49849           21         6       1.0       481        9
# 190159          8145          111        17       0.0       568        4
#
#          OUT_BYTES  OUT_PKTS  TCP_FLAGS  CLIENT_TCP_FLAGS  ...  \
# 878316        2056        29         24                24  ...
# 2022162      95560        98         27                27  ...
# 352143        1644        18         27                27  ...
# 1977974       2528        28         27                27  ...
# 2086978        178         2          0                 0  ...
# ...            ...       ...        ...               ...  ...
# 2370827       3276        40         27                27  ...
# 2000931        822        10         27                27  ...
# 269949         312         4          0                 0  ...
# 1905472        749        11         24                24  ...
# 190159         304         4          0                 0  ...
#
#          TCP_WIN_MAX_IN  TCP_WIN_MAX_OUT  ICMP_TYPE  ICMP_IPV4_TYPE  \
# 878316            17376            15928      31232             122
# 2022162           65160            14480      11008              43
# 352143            10136            10136      64000             250
# 1977974           14480            13032      38656             151
# 2086978               0                0          0               0
# ...                 ...              ...        ...             ...
# 2370827           15928            30408      57088             223
# 2000931            7240             7240      26112             102
# 269949                0                0          0               0
# 1905472           10136            10136      33792             132
# 190159                0                0          0               0
#
#          DNS_QUERY_ID  DNS_QUERY_TYPE  DNS_TTL_ANSWER  FTP_COMMAND_RET_CODE  \
# 878316              0               0               0                 125.0
# 2022162             0               0               0                   0.0
# 352143              0               0               0                   0.0
# 1977974             0               0               0                   0.0
# 2086978         23354               1              60                   0.0
# ...               ...             ...             ...                   ...
# 2370827             0               0               0                   0.0
# 2000931             0               0               0                   0.0
# 269949              0               0               0                   0.0
# 1905472             0               0               0                 229.0
# 190159              0               0               0                   0.0
#
#          Label  Attack
# 878316       0  Benign
# 2022162      0  Benign
# 352143       0  Benign
# 1977974      0  Benign
# 2086978      0  Benign
# ...        ...     ...
# 2370827      0  Benign
# 2000931      0  Benign
# 269949       0  Benign
# 1905472      0  Benign
# 190159       0  Benign
#
# [343278 rows x 43 columns]

# %%
df[df.drop(columns=['Attack']).duplicated()]["Attack"].value_counts()
# Out:
# Attack
# Fuzzers           157
# Exploits          153
# Reconnaissance    152
# DoS               151
# Backdoor          141
# Analysis          139
# Generic           134
# Name: count, dtype: int64

# %%
df["Label"].value_counts(normalize=True)
# Out:
# Label
# 0    0.961786
# 1    0.038214
# Name: proportion, dtype: float64
