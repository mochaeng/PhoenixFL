# %%
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_parquet("../datasets/pre-processed/NF-ToN-IoT-v2.parquet")

df
# Out:
#           L4_SRC_PORT  L4_DST_PORT  PROTOCOL  L7_PROTO  IN_BYTES  IN_PKTS  \
# 5787015         40637         8086         6       0.0        44        1
# 6052503         54473         4111         6       0.0        44        1
# 2828423         45025        24619         6       0.0        48        1
# 4177606         45577         8099         6       0.0        44        1
# 4835504         36945        12000         6       0.0        44        1
# ...               ...          ...       ...       ...       ...      ...
# 14059700        56554          443         6      91.0       276        5
# 9319187         46295           53        17       0.0        68        1
# 10782789        58528           80         6       7.0      1843        7
# 10611187        58442           53        17       0.0        68        1
# 2082824         31928        59127         6       0.0        48        1
#
#           OUT_BYTES  OUT_PKTS  TCP_FLAGS  CLIENT_TCP_FLAGS  ...  \
# 5787015           0         0          2                 2  ...
# 6052503           0         0          2                 2  ...
# 2828423           0         0          2                 2  ...
# 4177606           0         0          2                 2  ...
# 4835504          40         1         22                 2  ...
# ...             ...       ...        ...               ...  ...
# 14059700        120         2         18                18  ...
# 9319187         100         1          0                 0  ...
# 10782789        590         5         27                27  ...
# 10611187         68         1          0                 0  ...
# 2082824           0         0          2                 2  ...
#
#           TCP_WIN_MAX_IN  TCP_WIN_MAX_OUT  ICMP_TYPE  ICMP_IPV4_TYPE  \
# 5787015             1024                0          0               0
# 6052503             1024                0          0               0
# 2828423             4096                0          0               0
# 4177606             1024                0          0               0
# 4835504             1024                0          0               0
# ...                  ...              ...        ...             ...
# 14059700           29200            28960          0               0
# 9319187                0                0          0               0
# 10782789           29200             5792          0               0
# 10611187               0                0          0               0
# 2082824             4096                0          0               0
#
#           DNS_QUERY_ID  DNS_QUERY_TYPE  DNS_TTL_ANSWER  FTP_COMMAND_RET_CODE  \
# 5787015              0               0               0                     0
# 6052503              0               0               0                     0
# 2828423              0               0               0                     0
# 4177606              0               0               0                     0
# 4835504              0               0               0                     0
# ...                ...             ...             ...                   ...
# 14059700             0               0               0                     0
# 9319187          14668               1              11                     0
# 10782789             0               0               0                     0
# 10611187          7691              28               0                     0
# 2082824              0               0               0                     0
#
#           Label    Attack
# 5787015       0    Benign
# 6052503       0    Benign
# 2828423       1  scanning
# 4177606       0    Benign
# 4835504       0    Benign
# ...         ...       ...
# 14059700      1      ddos
# 9319187       1       xss
# 10782789      1       xss
# 10611187      1       xss
# 2082824       1  scanning
#
# [246770 rows x 43 columns]

# %%
df[df.drop(columns=['Attack']).duplicated()]["Attack"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df = df.drop(columns="Attack")

# %%
# Out:
# 0
