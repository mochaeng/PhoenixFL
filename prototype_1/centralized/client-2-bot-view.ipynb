# %%
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_parquet("../../datasets/pre-processed/NF-BoT-IoT-v2.parquet")

df
# Out:
#         L4_SRC_PORT  L4_DST_PORT  PROTOCOL  L7_PROTO  IN_BYTES  IN_PKTS  \
# 134300        20282           80        17     188.0        56        2
# 361802        17822           80         6       7.0       280        2
# 388728        46151           80         6       7.0       280        2
# 181816        23150           80         6       7.0       420        3
# 389062        16116           80         6       7.0       280        2
# ...             ...          ...       ...       ...       ...      ...
# 176638        21238           80        17     188.0        56        2
# 149756        33093           80         6       7.0       280        2
# 194682        34120           80         6       7.0       280        2
# 323498        13079           80        17     188.0        84        3
# 165021        19493           80        17     188.0        84        3
#
#         OUT_BYTES  OUT_PKTS  TCP_FLAGS  CLIENT_TCP_FLAGS  ...  TCP_WIN_MAX_IN  \
# 134300          0         0          0                 0  ...               0
# 361802          0         0          2                 2  ...             512
# 388728          0         0          2                 2  ...             512
# 181816          0         0          2                 2  ...             512
# 389062          0         0          2                 2  ...             512
# ...           ...       ...        ...               ...  ...             ...
# 176638          0         0          0                 0  ...               0
# 149756          0         0          2                 2  ...             512
# 194682          0         0          2                 2  ...             512
# 323498          0         0          0                 0  ...               0
# 165021          0         0          0                 0  ...               0
#
#         TCP_WIN_MAX_OUT  ICMP_TYPE  ICMP_IPV4_TYPE  DNS_QUERY_ID  \
# 134300                0          0               0             0
# 361802                0          0               0             0
# 388728                0          0               0             0
# 181816                0          0               0             0
# 389062                0      35840             140             0
# ...                 ...        ...             ...           ...
# 176638                0          0               0             0
# 149756                0      35840             140             0
# 194682                0          0               0             0
# 323498                0          0               0             0
# 165021                0          0               0             0
#
#         DNS_QUERY_TYPE  DNS_TTL_ANSWER  FTP_COMMAND_RET_CODE  Label  Attack
# 134300               0               0                     0      1    DDoS
# 361802               0               0                     0      1     DoS
# 388728               0               0                     0      1     DoS
# 181816               0               0                     0      1     DoS
# 389062               0               0                     0      1     DoS
# ...                ...             ...                   ...    ...     ...
# 176638               0               0                     0      1    DDoS
# 149756               0               0                     0      1     DoS
# 194682               0               0                     0      1     DoS
# 323498               0               0                     0      1    DDoS
# 165021               0               0                     0      1    DDoS
#
# [338913 rows x 43 columns]

# %%
df[df.drop(columns=['Attack']).duplicated()]["Attack"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df["Label"].value_counts(normalize=True)
# Out:
# Label
# 1    0.996412
# 0    0.003588
# Name: proportion, dtype: float64
